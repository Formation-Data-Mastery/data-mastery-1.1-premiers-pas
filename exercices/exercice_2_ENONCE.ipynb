# %% [markdown]
# # Exercice 2 — Choisir et créer des visualisations pertinentes
#
# **Difficulté :** Intermédiaire
# **Durée estimée :** 40 min
#
# ---
#
# ## Contexte
#
# Le directeur de production souhaite comprendre les tendances de la ligne de fabrication. On dispose du fichier `production_industrielle.csv` qui contient les relevés journaliers de production pour trois lignes.
#
# La donnée brute ne parle pas d'elle-même : c'est le graphique approprié qui révèle les patterns. Le choix du type de graphique n'est pas anodin — un mauvais choix peut masquer l'information importante ou induire en erreur.
#
# **Objectif :** Charger, nettoyer et visualiser les données de production en produisant 3 graphiques pertinents avec plotly, chacun accompagné d'une interprétation.
#
# ---
#
# ## Données
#
# Fichier : `../data/production_industrielle.csv`
#
# Colonnes disponibles :
# - `date` — jour de production
# - `ligne` — identifiant de la ligne (Ligne_1, Ligne_2, Ligne_3)
# - `produit` — type de produit fabriqué
# - `quantite_produite` — unités produites dans la journée
# - `quantite_defauts` — unités non conformes détectées
# - `temps_arret_min` — durée d'arrêt machine en minutes
# - `operateur` — équipe de travail (Equipe_Matin, Equipe_Apres_Midi, Equipe_Nuit)
#
# ---

# %% [markdown]
# ## Tâche 1 — Charger et nettoyer les données
#
# Charger le fichier CSV. Examiner les données et traiter :
# - Les valeurs manquantes dans `temps_arret_min`
# - Les valeurs négatives dans `quantite_defauts` (qui sont des erreurs de saisie)
# - Convertir la colonne `date` en type datetime

# %% [markdown]
# ## Tâche 2 — Graphique 1 : production totale par ligne
#
# Créer un **bar chart** (graphique en barres) montrant la production totale par ligne de production.
#
# Critères :
# - Type choisi : bar chart — justifier ce choix en commentaire
# - Titre, labels d'axes, couleurs différentes par barre
# - Interpréter le graphique en 2-3 phrases dans une cellule markdown

# %% [markdown]
# *Interprétation :*
#
# > *(à compléter)*

# %% [markdown]
# ## Tâche 3 — Graphique 2 : évolution quotidienne avec moyenne mobile
#
# Créer un **line chart** (graphique en courbes) montrant l'évolution quotidienne de la production totale sur l'ensemble des lignes, avec une **moyenne mobile sur 7 jours** superposée.
#
# Critères :
# - Agréger la production journalière toutes lignes confondues
# - Calculer la moyenne mobile 7 jours avec pandas
# - Afficher les deux courbes (production réelle + tendance) sur le même graphique
# - Légende claire, titre, axes labellisés
# - Interpréter le graphique

# %% [markdown]
# *Interprétation :*
#
# > *(à compléter)*

# %% [markdown]
# ## Tâche 4 — Graphique 3 : quantité produite vs défauts par équipe
#
# Créer un **scatter plot** (nuage de points) mettant en relation `quantite_produite` (axe X) et `quantite_defauts` (axe Y), avec les points **colorés par équipe** (`operateur`).
#
# Critères :
# - Un point = une entrée du dataset
# - Coloration par équipe avec une légende
# - Titre et labels d'axes explicites
# - Interpréter la relation observée

# %% [markdown]
# *Interprétation :*
#
# > *(à compléter)*

# %% [markdown]
# ## Tâche 5 — Bonus : temps d'arrêt vs défauts
#
# Créer un 4e graphique de votre choix montrant la relation entre `temps_arret_min` et `quantite_defauts`. Justifier le type de graphique choisi.

# %% [markdown]
# *Interprétation :*
#
# > *(à compléter)*
